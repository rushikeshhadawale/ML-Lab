# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
x = np.random.rand(300,2)

plt.figure(figsize=(7.5, 3.5))
plt.scatter(x[:,0],x[:,1], s=20, cmap='summer');
plt.show()
# Out:
# C:\Users\RUSHIKESH\AppData\Local\Temp\ipykernel_4604\1162472462.py:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x[:,0],x[:,1], s=20, cmap='summer');

# %%
kmeans = KMeans(n_clusters=3, max_iter=100)

# %%
kmeans.fit(x)
plt.figure(figsize=(7.5, 3.5))
plt.scatter(x[:,0],x[:,1], c=kmeans.labels_, s=20, cmap='summer')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],
            marker='x', c='r', s=50, alpha=0.9)
plt.show()
