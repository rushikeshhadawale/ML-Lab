# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randn(1000)

plt.hist(x)
plt.show()

# %%
import pandas as pd

# reading csv file 
df = pd.read_csv("C:\Train.csv")
df
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# 1                    5                  216                2
# 2                    2                  183                4
# 3                    3                  176                4
# 4                    2                  184                3
# ...                ...                  ...              ...
# 10994                1                  252                5
# 10995                1                  232                5
# 10996                4                  242                5
# 10997                2                  223                6
# 10998                5                  155                5
#
#       Product_importance Gender  Discount_offered  Weight_in_gms  \
# 0                    low      F                44           1233
# 1                    low      M                59           3088
# 2                    low      M                48           3374
# 3                 medium      M                10           1177
# 4                 medium      F                46           2484
# ...                  ...    ...               ...            ...
# 10994             medium      F                 1           1538
# 10995             medium      F                 6           1247
# 10996                low      F                 4           1155
# 10997             medium      M                 2           1210
# 10998                low      F                 6           1639
#
#        Reached.on.Time_Y.N
# 0                        1
# 1                        1
# 2                        1
# 3                        1
# 4                        1
# ...                    ...
# 10994                    1
# 10995                    0
# 10996                    0
# 10997                    0
# 10998                    0
#
# [10999 rows x 12 columns]

# %%
import pandas as pd
data={'A' :[1,2,3,4,5,5,3],'B' :['x','y','e','q','e','x','y']}
df=pd.DataFrame(data)
print("Original Dataframe")
print(df)
df_unique=df.drop_duplicates()
print("\n Dataframe after removing duplicate")
print(df_unique)
# Out:
# Original Dataframe
#    A  B
# 0  1  x
# 1  2  y
# 2  3  e
# 3  4  q
# 4  5  e
# 5  5  x
# 6  3  y
#
#  Dataframe after removing duplicate
#    A  B
# 0  1  x
# 1  2  y
# 2  3  e
# 3  4  q
# 4  5  e
# 5  5  x
# 6  3  y

# %%
import pandas as pd

df=pd.read_csv("C:\Train.csv")
print(df)

print ("Display the first few rows form csv file")
print(df.head())
